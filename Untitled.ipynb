# %%
import os

# %%
list(os.environ.keys())
# Out:
# ['DISTRIBUTED_COMPUTE_OPERATOR_WEBHOOK_SERVER_PORT_443_TCP_PORT',
#  'LC_ALL',
#  'MAX_RETRIES',
#  'DOMINO_GROUP_ID',
#  'PYTHON_VER',
#  'RUN_60C3C6F23469F801BEB411D0_SERVICE_PORT_HTTP',
#  'RUN_60C3EC9E3469F801BEB41269_PORT_9000_TCP_ADDR',
#  'LANG',
#  'RAY_60C3C6F23469F801BEB411D0_RAY_CLIENT_PORT_10001_TCP_ADDR',
#  'RUN_60C3C6F23469F801BEB411D0_PORT_80_TCP_PROTO',
#  'DISTRIBUTED_COMPUTE_OPERATOR_WEBHOOK_SERVER_PORT_443_TCP',
#  'RUN_60C3C6F23469F801BEB411D0_SERVICE_HOST',
#  'HOSTNAME',
#  'RUN_60C3C6F23469F801BEB411D0_SERVICE_PORT',
#  'RAY_60C3C6F23469F801BEB411D0_RAY_CLIENT_PORT_8265_TCP_ADDR',
#  'OLDPWD',
#  'DOMINO_RUN_NUMBER',
#  'RAY_60C3C6F23469F801BEB411D0_RAY_CLIENT_SERVICE_PORT_TCP_CLIENT',
#  'DOMINO_RUN_ID',
#  'DOMINO_PROJECT_OWNER',
#  'JAVA_HOME',
#  'RUN_60C3EC9E3469F801BEB41269_SERVICE_PORT_HTTP',
#  'RUN_60C3C6F23469F801BEB411D0_PORT_9000_TCP',
#  'CONDA_DIR',
#  'RUN_60C3EC9E3469F801BEB41269_PORT_80_TCP',
#  'PYTHONIOENCODING',
# ...
